# %%
import pandas as pd
import numpy as np

# %%
## Phase 1 :
# Load the raw messy data
df = pd.read_csv('Raw_Nigeria_Car_Sales_Data.CSV')

# %%
## Phase 2 :
#Business Audit: Check for data quality issues
print("---initial data info---")
print(df.info())
print("\n---Sample of Car_Brand Mistamched---")
print(df[["Car_Brand", "Car_Model"]].head(10))
# Out:
# ---initial data info---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6862 entries, 0 to 6861
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Sale_Date            6862 non-null   object
#  1   State                6862 non-null   object
#  2   City                 6862 non-null   object
#  3   Car_Brand            6862 non-null   object
#  4   Car_Model            6862 non-null   object
#  5   Car_Type             6862 non-null   object
#  6   Unit_Price_Naira     6862 non-null   int64
#  7   Quantity             6862 non-null   int64
#  8   Discount_Percent     6862 non-null   float64
#  9   Revenue_Naira        6862 non-null   float64
#  10  Customer_Type        6862 non-null   object
#  11  Delivery_Date        6862 non-null   object
#  12  Delivery_Status      6862 non-null   object
#  13  Delivery_Time_Hours  6862 non-null   int64
#  14  Warehouse            6862 non-null   object
#  15  Driver               6862 non-null   object
#  16  Car_Age              6862 non-null   int64
#  17  Region               6862 non-null   object
#  18  Sales_Rep            6862 non-null   object
# dtypes: float64(2), int64(4), object(13)
# memory usage: 1018.7+ KB
# None
#
# ---Sample of Car_Brand Mistamched---
#   Car_Brand Car_Model
# 0      Benz   GLE 450
# 1    Toyota   Corolla
# 2   Hyundai  Santa Fe
# 3    Toyota      Rav4
# 4     Honda      CR-V
# 5   Hyundai  Santa Fe
# 6    Toyota      Rav4
# 7      Benz    Sonata
# 8    Toyota    Sonata
# 9     Honda    Sonata

# %%
## Phase 3 :
# Define the master relationship between Brands and Models
brand_map = {
    'Toyota': ['Corolla', 'Camry', 'Highlander', 'Prado', 'Hilux', 'Venza', 'Sienna', 'Rav4'],
    'Honda': ['Accord', 'Civic', 'CR-V', 'Pilot',],
    'Benz': ['C300', 'GLE 450', 'E350', 'E-Class', 'GLC 350', 'GLK 350', 'C-Class'],
    'Lexus': ['ES 350', 'RX 350', 'GX 460','IS 250',],
    'Hyundai': ['Elantra', 'Santa Fe', 'Tucson', 'Sonata'],
    'Ford': ['Explorer', 'Edge', 'F-150', 'Focus'],
    'KIA': ['Rio', 'Sportage', 'Sorento', 'Cerato']
}

# Create a lookup dictionary
model_to_brand = {model: brand for brand, models in brand_map.items() for model in models}

# Fix: Map the correct Car_Brand to the Car_Model column
df['Brand'] = df['Car_Model'].map(model_to_brand)

print("Car_Brand/Model synchronization complete.")
# Check for NaNs again
print(f"Number of NaN values remaining: {df['Brand'].isna().sum()}")
# List every model that currently has a NaN Car_brand
missing_models = df[df['Brand'].isna()]['Car_Model'].unique()
print(missing_models)
# Out:
# Car_Brand/Model synchronization complete.
# Number of NaN values remaining: 0
# []

# %%
## Phase 6 :
# Convert to datetime objects
df['Sale_Date'] = pd.to_datetime(df['Sale_Date'])

# Drop the old column
if "Car_Brand" in df.columns:
    df = df.drop(columns=['Car_Brand'])
# Sorting data chronologically
df = df.sort_values(by='Sale_Date').reset_index(drop=True)# Final Visual Check
print("\n--- Cleaned Data Sample ---")
# Convert all column names to lower case
df.columns = df.columns.str.lower()
print(df.head())
# Out:
# --- Cleaned Data Sample ---
#    sale_date  state        city car_model       car_type  unit_price_naira  \
# 0 2021-03-01  Lagos    Alimosho     Camry   Foreign Used          16857142
# 1 2021-03-01  Enugu      Nsukka    Sonata   Foreign Used          11285714
# 2 2021-03-01    Edo      Ekpoma   Elantra  Nigerian Used           9000000
# 3 2021-03-01    FCT  Gwagwalada      CR-V   Foreign Used           8000000
# 4 2021-03-02   Osun     Ile-Ife      Rav4   Foreign Used          30000000
#
#    quantity  discount_percent  revenue_naira customer_type delivery_date  \
# 0         1             12.01   1.483260e+07    Individual    2021-03-06
# 1         1             11.20   1.002171e+07    Individual    2021-03-03
# 2         1              6.35   8.428500e+06    Individual    2021-03-07
# 3         1              9.46   7.243200e+06    Individual    2021-03-10
# 4         1             11.78   2.646600e+07    Individual    2021-03-06
#
#   delivery_status  delivery_time_hours warehouse driver  car_age       region  \
# 0         On-Time                   13     Lagos  Segun        7   South West
# 1         Delayed                    8     Lagos   John        7   South East
# 2         On-Time                    9     Lagos  Chuka        5  South South
# 3         On-Time                    9     Lagos   John       10        North
# 4         On-Time                   10     Lagos  Peter        3   South West
#
#   sales_rep    brand
# 0      Uche   Toyota
# 1       Ade  Hyundai
# 2     Funke  Hyundai
# 3      Uche    Honda
# 4     Ngozi   Toyota

# %%
## Phase 8 :
# Export to CSV
df.to_csv('Cleaned_Nigeria_Car_Sales_Data.csv', index=False)

print("Success! File saved as 'Cleaned_Nigeria_Car_Sales_Data.csv'.")
# Out:
# Success! File saved as 'Cleaned_Nigeria_Car_Sales_Data.csv'.
